# %% [markdown]
# ![1_f2-zeAOSNB4RGlqH9emTlQ.jpeg](attachment:1_f2-zeAOSNB4RGlqH9emTlQ.jpeg)

# %% [markdown]
# ### Question 1 : Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
#
# ### This task will be done in following steps :
# ###### 1. First get the webpage https://www.naukri.com/
# ###### 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# ###### 3. Then click the search button.
# ###### 4. Then scrape the data for the first 10 jobs results you get.
# ###### 5. Finally create a dataframe of the scraped data.

# %%
import selenium 
import pandas as pd
from selenium import webdriver 
import time
from selenium.common.exceptions import NoSuchElementException

# %%
Driver= webdriver.Chrome("chromedriver.exe")
Url="https://www.naukri.com/" 
Driver.get(Url)

# %%
Search_job= Driver.find_element_by_id('qsb-keyword-sugg')
Search_job.send_keys("Data Analyst")
Search_loc= Driver.find_element_by_id("qsb-location-sugg")
Search_loc.send_keys("Bangalore")
Search_btn=Driver.find_element_by_xpath('//button[@class="btn"]')
Search_btn.click()

# %%
Job_title=Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

Job_Title=[]
for i in Job_title:
    Job_Title.append(i.text)

# %%
Job_location=Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

Job_Location=[]
for i in Job_location:
    Job_Location.append(i.text)

# %%
Company_name= Driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

Company_Name=[]
for i in Company_name:
    Company_Name.append(i.text)

# %%
Experience_required= Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')

Experience_Require= []
for i in Experience_required:
    Experience_Require.append(i.text)

# %%
Job_Data= pd.DataFrame({})
Job_Data['Job_Title']=Job_Title
Job_Data['Job_Location']=Job_Location
Job_Data['Company_Name']=Company_Name
Job_Data['Experience_required']= Experience_Require
Job_Data=Job_Data[0:10]

# %%
Job_Data
# Out:
#                                            Job_Title  \
# 0                                       Data Analyst
# 1                  Data Analyst - Flipkart Analytics
# 2                                Senior Data Analyst
# 3     Business Data Analyst - Database Design/Mining
# 4  Urgent Openings For Data Analyst / Business An...
# 5                        Professional 1 Data Analyst
# 6   Business Data Analyst(BigId) - Capco - Bangalore
# 7                                Senior Data Analyst
# 8                                       Data Analyst
# 9                                       Data Analyst
#
#                                         Job_Location  \
# 0                                Bangalore/Bengaluru
# 1                     Bangalore/Bengaluru(Bellandur)
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4            Bangalore/Bengaluru\n(WFH during Covid)
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# ### Question 2 : Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
#
# ### This task will be done in following steps:
#
# ###### 1. First get the webpage https://www.naukri.com/
# ###### 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# ###### 3. Then click the search button.
# ###### 4. Then scrape the data for the first 10 jobs results you get.
# ###### 5. Finally create a dataframe of the scraped data.

# %%
Driver=webdriver.Chrome("chromedriver.exe")
Url="https://www.naukri.com/" 
Driver.get(Url)

# %%
Search_job= Driver.find_element_by_id('qsb-keyword-sugg')
Search_job.send_keys("Data Scientist")
Search_loc= Driver.find_element_by_id("qsb-location-sugg")
Search_loc.send_keys("Bangalore") 
Search_btn=Driver.find_element_by_xpath('//button[@class="btn"]')
Search_btn.click()

# %%
Job_title=Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

Job_Title=[]
for i in Job_title:
    Job_Title.append(i.text)

# %%
Job_location=Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

Job_Location= []
for i in Job_location:
    Job_Location.append(i.text)

# %%
Company_name= Driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

Company_Name=[]
for i in Company_name:
    Company_Name.append(i.text)

# %%
Url= Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

job_urls=[]
for i in Url:
    job_urls.append(i.get_attribute('href'))

# %%
Naukri_Data= pd.DataFrame({})
Naukri_Data['Job_Title']=Job_Title
Naukri_Data['Job_Location']=Job_Location
Naukri_Data['Company_Name']=Company_Name
Naukri_Data=Naukri_Data[0:10]

# %%
Naukri_Data
# Out:
#                                            Job_Title  \
# 0  Process Innovation Analyst - APAC/Data Scienti...
# 1                 Data Scientist: Advanced Analytics
# 2            Data Scientist: Artificial Intelligence
# 3                   Senior Data Scientist - Insights
# 4            Senior Data Scientist - Computer Vision
# 5  Senior Data Scientist | Fortune 500 Supermarke...
# 6              Data Scientist /Senior Data Scientist
# 7                 Sr Data Scientist / Data Scientist
# 8                              Senior Data Scientist
# 9    Forecasting Analyst/ Data Scientist (US Client)
#
#                                         Job_Location  \
# 0                     Bangalore/Bengaluru, Hyderabad
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# ### Question 3 : In this question you have to scrape data using the filters available on the webpage as shown below :
# ##### You have to use the location and salary filter.
# ##### You have to scrape data for “Data Scientist” designation for first 10 job results.
# ##### You have to scrape the job-title, job-location, company name, experience required.
# ##### The location filter to be used is “Delhi/NCR” The salary filter to be used is “3-6” lakhs
# #### The task will be done as shown in the below steps:
# ###### 1. first get the webpage https://www.naukri.com/
# ###### 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# ###### 3. Then click the search button.
# ###### 4. Then apply the location filter and salary filter by checking the respective boxes
# ###### 5. Then scrape the data for the first 10 jobs results you get.
# ###### 6. Finally create a dataframe of the scraped data.

# %%
Driver=webdriver.Chrome("chromedriver.exe")
url="https://www.naukri.com/" 
Driver.get(url)

# %%
Search_job= Driver.find_element_by_id('qsb-keyword-sugg')
Search_job.send_keys("Data Scientist")
Search_btn=Driver.find_element_by_xpath('//button[@class="btn"]')
Search_btn.click()

# %%
Filter_btn1=Driver.find_element_by_xpath('//span[@title="3-6 Lakhs"]')
Filter_btn1.click()

# %%
Filter_btn2=Driver.find_element_by_xpath('//span[@title="Delhi / NCR"]')
Filter_btn2.click()

# %%
Job_title= Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

Job_Title=[]
for i in Job_title:
    Job_Title.append(i.text)
Job_Title=Job_Title[0:10]

# %%
Job_location= Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

Job_Location=[]
for i in Job_location:
    Job_Location.append(i.text)
Job_Location=Job_Location[0:10]

# %%
Company_name= Driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

Company_Name= []
for i in Company_name:
    Company_Name.append(i.text)
    
Company_Name=Company_Name[0:10]

# %%
Experience_required= Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')

Experience_Required=[]
for i in Experience_required:
    Experience_Required.append(i.text)
    
Experience_Required=Experience_Required[0:10]

# %%
NCR_Jobs= pd.DataFrame({})
NCR_Jobs['Job_Title']=Job_Title
NCR_Jobs['Job_locations']= Job_Location
NCR_Jobs['Company_names']= Company_Name
NCR_Jobs['Experience_Required']= Experience_Required

# %%
NCR_Jobs
# Out:
#                                            Job_Title  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2  Job Opportunity || Data Scientist || HCL Techn...
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                               Data Scientist III-2
# 6           Urgent Hiring || Data Scientist || Delhi
# 7                                     Data Scientist
# 8                          Data Scientist Internship
# 9                           Associate Data Scientist
#
#                                        Job_locations  \
# 0                            Noida(Sector-126 Noida)
# 1                            Noida(Sector-126 Noida)
# 2                                        Delhi / NCR
# 3  Pune, Bangalore/Bengaluru, Delhi / NCR\n(WFH d...
# 4                            Noida, Gurgaon/Gurugram
# 5                                   Gurgaon/Gurugram
# ...

# %% [markdown]
# ### Question 4 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# ###### 1. Brand
# ###### 2. Product Description
# ###### 3. Price
# ###### To scrape the data you have to go through following steps:
# ###### 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# ###### 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# ###### 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual
# ###### 4. After scraping data from the first page, go to the “Next” Button at the bottom of the page , then click on it.
# ###### 5. Now scrape data from this page as usual
# ###### 6. Repeat this until you get data for 100 sunglasses.

# %%
Driver=webdriver.Chrome("chromedriver.exe")
Url="https://www.flipkart.com/" 
Driver.get(Url)

# %%
Search_product= Driver.find_element_by_xpath('//input[@class="_3704LK"]')
Search_product.send_keys("sunglasses")
Search_btn=Driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
Search_btn.click()

# %%
Page_1=Driver.find_elements_by_xpath('//a[@class="ge-49M _2Kfbh8"]')
Next_Page= Driver.find_elements_by_xpath('//a[@class="ge-49M"]')

# %%
URLS=[]
for i in Page_1:
    URLS.append(i.get_attribute('href'))
    
URLS
for i in Next_Page[0:2]:
    URLS.append(i.get_attribute('href'))

# %%
Brand_Name=[]
Product_Description=[]
Price=[]

for i in URLS:
    Brand=Driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
    for i in Brand:
        Brand_Name.append(i.text)
    
    Product_description=Driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
    for i in Product_description:
        Product_Description.append(i.text)
    
    price=Driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)

# %%
SunGlass=pd.DataFrame({})
SunGlass['Brand_Name']=Brand_Name[0:100]
SunGlass['Product_Description']=Product_Description[0:100]
SunGlass['Price']= Price[0:100]

# %%
SunGlass
# Out:
#         Brand_Name                                Product_Description Price
# 0   ROZZETTA CRAFT         UV Protection Round Sunglasses (Free Size)  ₹426
# 1   ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...  ₹349
# 2         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹513
# 3             SRPM             UV Protection Wayfarer Sunglasses (56)  ₹188
# 4           SUNBEE  UV Protection, Polarized, Mirrored Round Sungl...  ₹276
# ..             ...                                                ...   ...
# 95  ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...  ₹349
# 96       Rich Club                    Polarized Round Sunglasses (48)  ₹189
# 97      PHENOMENAL  UV Protection Retro Square Sunglasses (Free Size)  ₹329
# 98            hipe  Mirrored, UV Protection, Gradient Round Sungla...  ₹189
# 99         VILLAIN         Others Retro Square Sunglasses (Free Size)  ₹549
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Question 5 : Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/appleiphone11black64gbincludesearpodspoweradapter/p/itm0f37c2240b217pid=MOBFKCTSVZAXUHGR&lid=LSTMBFKCTSVZAXUHGREPBFGI&marketplace.
#
# ###### When you will open the above link you will reach to the below shown webpage .
# ###### 1. Rating
# ###### 2. Review_summary
# ###### 3. Full review
# ###### 4. You have to scrape this data for first 100 reviews.

# %%
Driver = webdriver.Chrome('chromedriver.exe')
Url= "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace"
Driver.get(Url)

# %%
Page_1=Driver.find_element_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
URL= Driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')

# %%
Page_1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="dd8ee222-0c2a-4073-a1d8-df7818d04c61")>

# %%
URL
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="b7df54fd-0247-4fa2-8b5d-cdf5f4c5ce2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="f9c27a50-0b5e-4fba-92cc-3d0abbf2904d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="3cf0b13c-4eea-4570-8141-d61075d9ffe0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="b3783515-7e9e-4b43-8d63-c2f731dbe615")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="d1722894-832a-48cd-8ac8-d442bc5aef5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1fca66cf0715d5a61d111cd6036e6fed", element="d8993d24-ee02-4e31-9eb1-ee4be278fca6")>,
# ...

# %%
Urls=[]
Urls.append(Page_1.get_attribute('href'))

for i in URL:
    Urls.append(i.get_attribute('href'))

# %%
Rating=[]
Review_summary=[]
Full_review=[]

for i in Urls:
    
    Ratings=Driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    
    for i in Ratings:
        Rating.append(i.text)
        
    review_summary=Driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    
    for i in review_summary:
        Review_summary.append(i.text)
        
    full_review=Driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    
    for i in full_review:
        Full_review.append(i.text)

# %%
Phone_rating=pd.DataFrame({})
Phone_rating['Rating']=Rating
Phone_rating['Review_summary']=Review_summary
Phone_rating['Full_review']= Full_review
Phone_rating=Phone_rating[0:100]

# %%
Phone_rating
# Out:
#    Rating       Review_summary  \
# 0       5            Brilliant
# 1       5       Simply awesome
# 2       5     Perfect product!
# 3       5    Worth every penny
# 4       5            Fabulous!
# ..    ...                  ...
# 95      5  Best in the market!
# 96      5        Great product
# 97      4          Good choice
# 98      5    Worth every penny
# 99      5   Highly recommended
#
#                                           Full_review
# 0   The Best Phone for the Money\n\nThe iPhone 11 ...
# 1   Really satisfied with the Product I received.....
# 2   Amazing phone with great cameras and better ba...
# 3   Previously I was using one plus 3t it was a gr...
# 4   This is my first iOS phone. I am very happy wi...
# ..                                                ...
# 95  Great iPhone very snappy experience as apple k...
# 96  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 97  So far it’s been an AMAZING experience coming ...
# ...

# %% [markdown]
# ### Question 6 : Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# ###### You have to scrape 4 attributes of each sneaker:
# ###### 1. Brand
# ###### 2. Product Description
# ###### 3. Price

# %%
Driver=webdriver.Chrome("chromedriver.exe")
Url="https://www.flipkart.com/" 
Driver.get(Url)

# %%
Search_product= Driver.find_element_by_xpath('//input[@class="_3704LK"]')
Search_product.send_keys("sneakers")
Search_btn=Driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
Search_btn.click()

# %%
Page_1=Driver.find_elements_by_xpath('//a[@class="ge-49M _2Kfbh8"]')
URL= Driver.find_elements_by_xpath('//a[@class="ge-49M"]')

# %%
Urls=[]
for i in Page_1:
    Urls.append(i.get_attribute('href'))
Urls

for i in URL[0:2]:
    Urls.append(i.get_attribute('href'))

# %%
Brand_name=[]
Product_Description=[]
Price=[]

for i in Urls:
    Brand=Driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
    for i in Brand:
        Brand_name.append(i.text)
    try:
        Product_Desc=Driver.find_elements_by_xpath('//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
        for i in Product_Desc:
            Product_Description.append(i.text)
    except:
            Product_Description.append("----")
    
    price=Driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)

# %%
Sneakers_Data=pd.DataFrame({})
Sneakers_Data['Brand_name']=Brand_name[0:100]
Sneakers_Data['Product_Description']=Product_Description[0:100]
Sneakers_Data['Price']= Price[0:100]
Sneakers_Data
# Out:
#       Brand_name        Product_Description   Price
# 0       Neeman's           Sneakers For Men  ₹2,399
# 1          EEKEN           Sneakers For Men  ₹2,399
# 2        Numenzo           Sneakers For Men    ₹479
# 3        Wlinzak           Sneakers For Men    ₹450
# 4      SCATCHITE  Sneakers Sneakers For Men    ₹398
# ..           ...                        ...     ...
# 95    LEE COOPER           Sneakers For Men  ₹2,099
# 96  Robbie jones           Sneakers For Men    ₹499
# 97      Kreverse           Sneakers For Men    ₹199
# 98      PACIFIER           Sneakers For Men    ₹499
# 99   bacca bucci           Sneakers For Men  ₹1,573
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Question 7 : Go to the link - https://www.myntra.com/shoes
# ###### Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe

# %%
Driver= webdriver.Chrome("chromedriver.exe")
Url="https://www.myntra.com/shoes" 
Driver.get(Url)

# %%
Price_range=Driver.find_element_by_xpath('//input[@class="price-input" and @value="7149.0 TO 14099.0"]')
Price_range
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="62bad4f9887a7be74c3176b464bd546d", element="c9ce5c47-1421-4a2c-be3f-48a63df736ba")>

# %%
Color_range=Driver.find_element_by_xpath('//span[@data-colorhex="black"]')
Color_range.click()

# %%
Next_btn= Driver.find_element_by_xpath('//li[@class="pagination-next"]')

# %%
Brand=[]
Short_summary=[]
Price=[]

for i in range(1,3):
    brand=Driver.find_elements_by_xpath('//h3[@class="product-brand"]')
    for i in brand:
        Brand.append(i.text)
        
    short_summary=Driver.find_elements_by_xpath('//h4[@class="product-product"]')
    
    for i in short_summary:
        Short_summary.append(i.text)
        
    price=Driver.find_elements_by_xpath('//div[@class="product-price"]')
    
    for i in price:
        Price.append(i.text)
    
Next_btn.click()

# %%
Shoes_Data= pd.DataFrame({})
Shoes_Data['Brand']=Brand
Shoes_Data['Short_summary']= Short_summary
Shoes_Data['Price']=Price
Shoes_Data
# Out:
#                       Brand                    Short_summary  \
# 0                       H&M              Chunky Combat Boots
# 1                    ADIDAS   Men Woven Design Running Shoes
# 2        Street Style Store  Women Suede High-Top Flat Boots
# 3                      Puma            Men Bent IDP Sneakers
# 4                    Campus                Men Running Shoes
# ..                      ...                              ...
# 95  Bond Street By Red Tape       Men Colourblocked Sneakers
# 96          PUMA Motorsport    Unisex Scuderia Ferrari Shoes
# 97                   ADIDAS          Men Orion Running Shoes
# 98                 Roadster   Men Mid-Top Casual Derby Shoes
# 99                     Nike    Men Zoom Span 4 Running Shoes
#
#                              Price
# 0                         Rs. 2699
# 1        Rs. 2009Rs. 2999(33% OFF)
# 2    Rs. 1199Rs. 1999(Rs. 800 OFF)
# 3        Rs. 1599Rs. 3999(60% OFF)
# 4        Rs. 1189Rs. 1699(30% OFF)
# ...

# %% [markdown]
# ### Question 8 : Go to webpage https://www.amazon.in/
# ###### Enter “Laptop” in the search field and then click the search icon.
# ###### Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” After setting the filters scrape first 10 laptops data. You have to scrape attributes for each laptop:
# ###### 1. Title
# ###### 2. Ratings
# ###### 3. Price

# %%
Driver= webdriver.Chrome("chromedriver.exe")
Url="https://www.amazon.in/" 
Driver.get(Url)

# %%
Search_product= Driver.find_element_by_xpath('//input[@type="text"]')
Search_product.send_keys("Laptop")
Search_btn=Driver.find_element_by_xpath('//input[@id="nav-search-submit-button"]')
Search_btn.click()

# %%
Filter_btn_1=Driver.find_element_by_xpath('//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span')
Filter_btn_1.click()

# %%
title=Driver.find_elements_by_xpath('//span[@class="a-size-medium a-color-base a-text-normal"]')
Title=[]
for i in title[0:10]:
    Title.append(i.text)
    
price=Driver.find_elements_by_xpath('//span[@class="a-price-whole"]')    
Price=[]
for i in price[0:10]:
    Price.append(i.text)

# %%
Url= Driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')

Laptop_urls=[]
for i in Url:
    Laptop_urls.append(i.get_attribute('href'))

# %%
Rating=[]
for i in Laptop_urls[0:10]:
    Driver.get(i)
    time.sleep(5)
    try:
        rating=Driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]')
        Rating.append(rating.text)
    except:
        Rating.append('--')

# %%
Laptop_Data= pd.DataFrame({})
Laptop_Data['Title']=Title
Laptop_Data['Price']= Price
Laptop_Data['Rating']= Rating

# %%
Laptop_Data
# Out:
#                                                Title     Price        Rating
# 0  ASUS TUF Dash F15 (2021) 15.6-inch (39.62 cms)...    93,990  3.9 out of 5
# 1  ASUS ZenBook 13 OLED (2021) Intel Core i7-1165...    99,057  4.2 out of 5
# 2  ASUS TUF Gaming F17 (2021), 17.3-inch (43.94 c...  1,13,990  4.6 out of 5
# 3  Mi Notebook Horizon Edition 14 Intel Core i7-1...    56,990  4.2 out of 5
# 4  HP Pavilion x360 11th Gen Intel Core i7 14-inc...    84,990  4.3 out of 5
# 5  HP Pavilion (2021) Intel 11th Gen Core i7 14 i...    84,990  4.3 out of 5
# 6  Dell 14 (2021) i7-1195G7 2in1 Touch Screen Lap...    88,508  4.6 out of 5
# 7  Lenovo Yoga 7 11th Gen Intel Core i7 14" Full ...    98,700  4.2 out of 5
# 8  ASUS TUF Dash F15 (2021) 15.6-inch (39.62 cms)...    93,990  3.9 out of 5
# 9  ASUS TUF Gaming F15 (2021), 15.6-inch (39.62 c...    96,990  4.8 out of 5

# %% [markdown]
# ### Question 9 : Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# ###### This task will be done in following steps:
# ###### 1. First get the webpage https://www.ambitionbox.com/
# ###### 2. Click on the Job option.
# ###### 3. After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter“Data Scientist” and click on search button.
# ###### 4. You will reach to the following web page click on location and in place of “Search location” enter“Noida” and select location “Noida”.
# ###### 5. Then scrape the data for the first 10 jobs results you get on the above shown page.
# ###### 6. Finally create a dataframe of the scraped data.

# %%
Driver= webdriver.Chrome("chromedriver.exe")
Url= "https://www.ambitionbox.com/"
Driver.get(Url)

# %%
Search_btn_1=Driver.find_element_by_xpath('//nav[@class="left-section"]/a[6]')
Search_btn_1.click()

# %%
Search_job= Driver.find_element_by_xpath('// input[@type="search"]')
Search_job.send_keys("Data Scientist")
Search_btn_2=Driver.find_element_by_xpath('//button[@class="ab_btn search-btn round"]')
Search_btn_2.click()

# %%
Search_btn_3= Driver.find_element_by_xpath('//div[@class="filter-item"][2]')
Search_btn_3.click()

# %%
Search_btn_4= Driver.find_element_by_xpath('//*[@id="filters-row"]/div/div/div[2]/div[2]/div/div[2]/input')

# %%
Search_btn_4.send_keys("Noida")

# %%
Search_loc= Driver.find_element_by_xpath('//*[@id="filters-row"]/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label')

# %%
Search_loc.click()

# %%
Job_Title=[]

Job_title=Driver.find_elements_by_xpath('//a[@class="title noclick"]')
for i in Job_title[0:10]:
    Job_Title.append(i.text)

# %%
Company_Name=[]

Company_name=Driver.find_elements_by_xpath('//p[@class="company body-medium"]')
for i in Company_name[0:10]:
    Company_Name.append(i.text)

# %%
Post_Date=[]

Post=Driver.find_elements_by_xpath('//span[@class="body-small-l"]')
for i in Post[0:20]:
    Post_Date.append(i.text)
Post_Date=Post_Date[0:21:2]

# %%
Company_Rating=[]

Rating=Driver.find_elements_by_xpath('//span[@class="body-small"]')
for i in Rating:
    Company_Rating.append(i.text)

# %%
Job_Data= pd.DataFrame({})
Job_Data['Job_Title']=Job_Title
Job_Data['Company_Name']=Company_Name
Job_Data['Post_Date']=Post_Date[0:10]
Job_Data['Company_Rating']= Company_Rating[0:10]

# %%
Job_Data
# Out:
#                                            Job_Title  \
# 0                                     Data Scientist
# 1      Urgent Requirement || Data Scientist || Noida
# 2                          Group Lead-Data Scientist
# 3  Jubilant FoodWorks - Data Scientist - Deep Lea...
# 4                                     Data Scientist
# 5          Urgent Vacancy || Data Scientist || Noida
# 6      Urgent Requirement || Data Scientist || Noida
# 7                              Senior Data Scientist
# 8       Data Scientist - Machine Learning (5-14 yrs)
# 9  Data Scientist - Data Science/Model Developmen...
#
#                                      Company_Name Post_Date Company_Rating
# 0  Optum Global Solutions (India) Private Limited   10d ago            4.1
# 1                                Steria India Ltd    3d ago            4.1
# 2                            Ameriprise Financial    5d ago            4.1
# 3                      Jubilant Foodworks Limited    2d ago            3.9
# ...

# %% [markdown]
# ### Question 10 : Write a python program to scrape the salary data for Data Scientist designation. You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary.
# ###### The above task will be, done as shown in the below steps:
# ###### 1. First get the webpage https://www.ambitionbox.com/
# ###### 2. Click on the salaries option as shown
# ###### 3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” andthen click on “Data Scientist”.
# ###### 4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, averagesalary, minimum salary, maximum salary, experience required.
# ###### 5. Store the data in a dataframe.

# %%
Driver= webdriver.Chrome("chromedriver.exe")
Url= "https://www.ambitionbox.com/"
Driver.get(Url)

# %%
Search_btn=Driver.find_element_by_xpath('//nav[@class="left-section"]/a[4]')
Search_btn.click()

# %%
Search_job= Driver.find_element_by_xpath('// input[@class="tt-input"]')
Search_job.send_keys("Data Scientist")

# %%
Company_Name=[]

Company_name=Driver.find_elements_by_xpath('//div[@class="name"]')
for i in Company_name[0:10]:
    Company_Name.append(i.text.split("\n")[0])

# %%
Total_Salary=[]

Total_salary=Driver.find_elements_by_xpath('//div[@class="name"]')
for i in Total_salary[0:10]:
    Total_Salary.append(i.text.split("\n")[1])

# %%
Average_Salary=[]

Average_salary=Driver.find_elements_by_xpath('//p[@class="averageCtc"]')
for i in Average_salary[0:10]:
    Average_Salary.append(i.text)

# %%
Minimum_Salary=[]

Minimum_salary=Driver.find_elements_by_xpath('//div[@class="value body-medium"]')
for i in Minimum_salary[0:10]:
    Minimum_Salary.append(i.text)

# %%
Maximum_Salary=[]

Maximum_salary=Driver.find_elements_by_xpath('//div[@class="salary-values"]')
for i in Maximum_salary[0:10]:
    Maximum_Salary.append(i.text.split("\n")[1])

# %%
Experience_Required=[]

Experience_required=Driver.find_elements_by_xpath('//div[@class="salaries sbold-list-header"]')
for i in Experience_required[0:10]:
    Experience_Required.append(i.text.split("\n")[2])

# %%
Job_Data= pd.DataFrame({})
Job_Data['Company_Name']=Company_Name
Job_Data['Total_Salary']=Total_Salary
Job_Data['Average_Salary']= Average_Salary
Job_Data['Minimum_Salary']= Minimum_Salary
Job_Data['Maximum_Salary']= Maximum_Salary
Job_Data['Experience_Required']= Experience_Required

# %%
Job_Data
# Out:
#                Company_Name          Total_Salary Average_Salary  \
# 0                  Ab Inbev  based on 10 salaries        ₹ 19.4L
# 1                     Optum  based on 22 salaries        ₹ 15.1L
# 2         Fractal Analytics  based on 60 salaries        ₹ 14.7L
# 3           Tiger Analytics  based on 24 salaries        ₹ 13.4L
# 4              UnitedHealth  based on 45 salaries        ₹ 13.3L
# 5                   Verizon  based on 14 salaries        ₹ 12.7L
# 6  Ganit Business Solutions  based on 12 salaries        ₹ 12.4L
# 7                  Deloitte  based on 45 salaries        ₹ 11.2L
# 8             Ernst & Young  based on 26 salaries        ₹ 11.1L
# 9                  Ericsson  based on 43 salaries        ₹ 10.9L
#
#   Minimum_Salary Maximum_Salary Experience_Required
# 0        ₹ 15.0L        ₹ 23.0L           4 yrs exp
# 1        ₹ 23.0L        ₹ 21.3L         3-4 yrs exp
# 2        ₹ 11.0L        ₹ 20.8L         2-4 yrs exp
# ...
